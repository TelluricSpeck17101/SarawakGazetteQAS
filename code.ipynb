# %% [markdown]
# # 0. Parameters

# %%
document_path = "./digitized_gazette"
cleaned_document_path = "./cleaned"
embedding_store_path = "./embeddings"
model_name = "Nous-Hermes-2-Mistral-7B-DPO.Q4_0.gguf"
chunk_size = 1200
chunk_overlap = 300
chunk_count = 5
# if chunk_size * chunk_count + question_size > 8000, the llm will crash
# processing time is also affected, proportional to chunk_size * chunk_count + question_size

random_seed = 0
question_contexts_filepath = "./question_contexts.txt"
reference_answers_filepath = "./reference_answers.txt"
generated_answers_path = "./generated_answers"
caqa_max = 500
test_subset = {
    "saga": (1, 100),
    "caqa": (1, caqa_max)
}
caqa_filepath = "./test.json"
caqa_subset_filepath = "./caqa_subset.json"

# %% [markdown]
# ## 0.1. Setup

# %%
# %pip install --upgrade langchain langchain-community langchainhub gpt4all langchain-chroma nltk pyside6
# Out:
# Requirement already satisfied: langchain in c:\users\user\anaconda3\lib\site-packages (0.2.10)
# Requirement already satisfied: langchain-community in c:\users\user\anaconda3\lib\site-packages (0.2.9)
# Requirement already satisfied: langchainhub in c:\users\user\anaconda3\lib\site-packages (0.1.20)
# Requirement already satisfied: gpt4all in c:\users\user\anaconda3\lib\site-packages (2.7.0)
# Requirement already satisfied: langchain-chroma in c:\users\user\anaconda3\lib\site-packages (0.1.2)
# Requirement already satisfied: nltk in c:\users\user\anaconda3\lib\site-packages (3.8.1)
# Requirement already satisfied: pyside6 in c:\users\user\anaconda3\lib\site-packages (6.7.2)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\user\anaconda3\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\user\anaconda3\lib\site-packages (from langchain) (2.0.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\user\anaconda3\lib\site-packages (from langchain) (3.9.3)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.22 in c:\users\user\anaconda3\lib\site-packages (from langchain) (0.2.22)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\user\anaconda3\lib\site-packages (from langchain) (0.2.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\user\anaconda3\lib\site-packages (from langchain) (0.1.77)
# Requirement already satisfied: numpy<2,>=1 in c:\users\user\anaconda3\lib\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\user\anaconda3\lib\site-packages (from langchain) (1.10.12)
# Requirement already satisfied: requests<3,>=2 in c:\users\user\anaconda3\lib\site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\user\anaconda3\lib\site-packages (from langchain) (8.3.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\user\anaconda3\lib\site-packages (from langchain-community) (0.6.5)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\user\anaconda3\lib\site-packages (from langchainhub) (23.2)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.31.0.2 in c:\users\user\anaconda3\lib\site-packages (from langchainhub) (2.31.0.20240406)
# Requirement already satisfied: tqdm in c:\users\user\anaconda3\lib\site-packages (from gpt4all) (4.65.0)
# Requirement already satisfied: chromadb<0.6.0,>=0.4.0 in c:\users\user\anaconda3\lib\site-packages (from langchain-chroma) (0.4.24)
# Requirement already satisfied: fastapi<1,>=0.95.2 in c:\users\user\anaconda3\lib\site-packages (from langchain-chroma) (0.111.0)
# Requirement already satisfied: click in c:\users\user\anaconda3\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\user\anaconda3\lib\site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\user\anaconda3\lib\site-packages (from nltk) (2023.10.3)
# Requirement already satisfied: shiboken6==6.7.2 in c:\users\user\anaconda3\lib\site-packages (from pyside6) (6.7.2)
# Requirement already satisfied: PySide6-Essentials==6.7.2 in c:\users\user\anaconda3\lib\site-packages (from pyside6) (6.7.2)
# Requirement already satisfied: PySide6-Addons==6.7.2 in c:\users\user\anaconda3\lib\site-packages (from pyside6) (6.7.2)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.3)
# Requirement already satisfied: build>=1.0.3 in c:\users\user\anaconda3\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.2.1)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in c:\users\user\anaconda3\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.7.3)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\user\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.29.0)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\user\anaconda3\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\user\anaconda3\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (4.9.0)
# Requirement already satisfied: pulsar-client>=3.1.0 in c:\users\user\anaconda3\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (3.5.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\user\anaconda3\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.17.3)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\user\anaconda3\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.24.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\user\anaconda3\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.24.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\user\anaconda3\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.45b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\user\anaconda3\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.24.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\user\anaconda3\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.19.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\user\anaconda3\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\user\anaconda3\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (7.4.0)
# Requirement already satisfied: importlib-resources in c:\users\user\anaconda3\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (6.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\user\anaconda3\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.63.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\user\anaconda3\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (4.1.3)
# Requirement already satisfied: typer>=0.9.0 in c:\users\user\anaconda3\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.12.3)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\user\anaconda3\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (29.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\user\anaconda3\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\user\anaconda3\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (3.10.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\user\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.21.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\user\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in c:\users\user\anaconda3\lib\site-packages (from fastapi<1,>=0.95.2->langchain-chroma) (0.37.2)
# Requirement already satisfied: fastapi-cli>=0.0.2 in c:\users\user\anaconda3\lib\site-packages (from fastapi<1,>=0.95.2->langchain-chroma) (0.0.3)
# Requirement already satisfied: httpx>=0.23.0 in c:\users\user\anaconda3\lib\site-packages (from fastapi<1,>=0.95.2->langchain-chroma) (0.27.0)
# Requirement already satisfied: jinja2>=2.11.2 in c:\users\user\anaconda3\lib\site-packages (from fastapi<1,>=0.95.2->langchain-chroma) (3.1.3)
# Requirement already satisfied: python-multipart>=0.0.7 in c:\users\user\anaconda3\lib\site-packages (from fastapi<1,>=0.95.2->langchain-chroma) (0.0.9)
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in c:\users\user\anaconda3\lib\site-packages (from fastapi<1,>=0.95.2->langchain-chroma) (5.4.0)
# Requirement already satisfied: email_validator>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from fastapi<1,>=0.95.2->langchain-chroma) (2.1.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\user\anaconda3\lib\site-packages (from langchain-core<0.3.0,>=0.2.22->langchain) (1.33)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2024.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\user\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.1)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm->gpt4all) (0.4.6)
# Requirement already satisfied: pyproject_hooks in c:\users\user\anaconda3\lib\site-packages (from build>=1.0.3->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.1.0)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from email_validator>=2.0.0->fastapi<1,>=0.95.2->langchain-chroma) (2.6.1)
# Requirement already satisfied: anyio in c:\users\user\anaconda3\lib\site-packages (from httpx>=0.23.0->fastapi<1,>=0.95.2->langchain-chroma) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\user\anaconda3\lib\site-packages (from httpx>=0.23.0->fastapi<1,>=0.95.2->langchain-chroma) (1.0.5)
# Requirement already satisfied: sniffio in c:\users\user\anaconda3\lib\site-packages (from httpx>=0.23.0->fastapi<1,>=0.95.2->langchain-chroma) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\user\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.23.0->fastapi<1,>=0.95.2->langchain-chroma) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from jinja2>=2.11.2->fastapi<1,>=0.95.2->langchain-chroma) (2.1.3)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\user\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.22->langchain) (2.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\user\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\user\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (2.29.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\user\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.58.0)
# Requirement already satisfied: requests-oauthlib in c:\users\user\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\user\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (3.2.2)
# Requirement already satisfied: coloredlogs in c:\users\user\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\user\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma) (24.3.25)
# Requirement already satisfied: protobuf in c:\users\user\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma) (3.20.3)
# Requirement already satisfied: sympy in c:\users\user\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.12)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\user\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.2.14)
# Requirement already satisfied: importlib-metadata<=7.0,>=6.0 in c:\users\user\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (7.0.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\user\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.63.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.24.0 in c:\users\user\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.24.0)
# Requirement already satisfied: opentelemetry-proto==1.24.0 in c:\users\user\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.24.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.45b0 in c:\users\user\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.45b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.45b0 in c:\users\user\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.45b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.45b0 in c:\users\user\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.45b0)
# Requirement already satisfied: opentelemetry-util-http==0.45b0 in c:\users\user\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.45b0)
# Requirement already satisfied: setuptools>=16.0 in c:\users\user\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (68.2.2)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.14.1)
# Requirement already satisfied: asgiref~=3.0 in c:\users\user\anaconda3\lib\site-packages (from opentelemetry-instrumentation-asgi==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in c:\users\user\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\user\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (2.2.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\user\anaconda3\lib\site-packages (from tokenizers>=0.13.2->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.23.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\user\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\user\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (13.3.5)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\user\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\user\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\user\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\user\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\user\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->langchain-chroma) (12.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\user\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\user\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (4.9)
# Requirement already satisfied: filelock in c:\users\user\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<0.6.0,>=0.4.0->langchain-chroma) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\user\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<0.6.0,>=0.4.0->langchain-chroma) (2023.10.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\user\anaconda3\lib\site-packages (from importlib-metadata<=7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (3.17.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\user\anaconda3\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\user\anaconda3\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (2.15.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\user\anaconda3\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma) (10.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\user\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\user\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma) (3.4.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\user\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\user\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.4.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain import hub
from langchain_community.document_loaders import TextLoader
from langchain_community.embeddings import GPT4AllEmbeddings
from langchain_community.llms import GPT4All
from langchain_community.utils.math import cosine_similarity
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_chroma import Chroma
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from nltk.metrics import scores
from pathlib import Path
from PySide6 import QtCore, QtWidgets
from statistics import mean, median, stdev
from time import perf_counter_ns
import json, nltk, random, re, time

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# # 1. Text Cleaning

# %% [markdown]
# ## 1.1. Regular Expression Creation

# %%
# make a regular expression that matches invalid characters or space characters after the first
# only characters in the set [^\s!-;?A-\]_a-z‘’“”—£] are valid
remove_invalid_regex = re.compile(r'[^\s!-;?A-\]_a-z‘’“”—£]+')
remove_excess_spaces_regex = re.compile(r'(\s)\s+')
def clean_str(to_clean_str):
    removed_invalid_str = remove_invalid_regex.sub(' ', to_clean_str)
    return remove_excess_spaces_regex.sub('\\1', removed_invalid_str)

# %%
# test the regular expression
to_clean = "This text contains¬“special” characters that need   to be removed,\n\n\n\nsometimes across multiple lines."
print(clean_str(to_clean))
# Out:
# This text contains “special” characters that need to be removed,
# sometimes across multiple lines.

# %% [markdown]
# ## 1.2. Clean Documents

# %%
statistics = {"total": {"files": 0, "tokens": 0}}
tokenizer = nltk.tokenize.word_tokenize

for file_path in Path(document_path).rglob('*.txt'):
    year = file_path.parent.stem
    if year not in statistics:
        statistics[year] = {"files": 0, "tokens": 0}

    statistics[year]["files"] += 1
    statistics["total"]["files"] += 1
    
    cleaned_filename = year + '-' + file_path.name
    with file_path.open(encoding='utf-8', errors='ignore') as to_clean_file:
        to_clean_str = to_clean_file.read()
        cleaned_str = clean_str(to_clean_str)
    with open(Path(cleaned_document_path) / cleaned_filename, 'w', encoding='utf-8') as cleaned_file:
        cleaned_file.write(cleaned_str)

    len_tokens = len(tokenizer(to_clean_str))
    statistics[year]["tokens"] += len_tokens
    statistics["total"]["tokens"] += len_tokens

# %%
# this is for getting a pretty-printed table of the file statistics
print("Year\tFiles\tTokens")
for year,data in statistics.items():
    print(year, data["files"], data["tokens"], sep="\t")
# Out:
# Year	Files	Tokens
# total	249	4178719
# 1907	11	248237
# 1919	22	226873
# 1920	27	256913
# 1922	12	252174
# 1926	12	280533
# 1927	11	214923
# 1928	12	121251
# 1929	6	93030
# 1930	12	271482
# 1931	11	246402
# 1932	12	189186
# 1933	12	112095
# 1934	11	65673
# 1935	12	187264
# 1936	12	266664
# 1937	12	210850
# 1939	1	13978
# 1941	1	16862
# 1947	12	260970
# 1948	12	275835
# 1949	1	28910
# 1951	1	18168
# 1953	10	212656
# 1958	4	107790

# %% [markdown]
# # 2. Embedding Database Creation

# %% [markdown]
# ## 2.1. Load Documents

# %%
docs = []
for file_path in Path(cleaned_document_path).glob('*.txt'):
    loader = TextLoader(file_path, autodetect_encoding=True)
    docs += loader.load()

# %%
# verify documents have been loaded properly
print("Length:", len(docs[0].page_content))
print("Excerpt:", docs[0].page_content[:5000])
# Out:
# Length: 93576
# Excerpt:
# VOL. XXXVII.
# No. 495.
# Price	THURSDAY, APRIL 4, 1907.	10 cents.
# CONTENTS.
# BIIITH.
# ORDERS:Sailors taking dischargeAdulteration of Gutta .IimgknrLeper CampFirearms.
# NOTIFICATIONS :Outstation Money Orders-Postcards -Money Orders Advice of Payment.
# NOTICES :- Bankruptcy Court (Kuching)Probate (Simang- gang)To Master? of vessels entering SadongBankruptcy (Bau)	Bankruptcy (Kabong)Sale of Land Grant No.
# 800Wanted, Land Grant No. 842 of 3rd March 1907 Sale of Land Grants 684 and 792.
# STRAITS SETTLEMENTS COINAGE PROCLAMATIONAPPOINTMENTS SARAWAK RACKS. 1907 THE ADVANTAGES OF A GOLD COINAGE THE CHINESE INSTITUTECLAY PIGEON SHOOTING AT Smu Ova NOTES.
# MONTHLY REPORTS:Lower Rejnng-Baram--Lundu- -Sadong Ma tang EstateBintnluBauKalakaSimanggang M ukaOyn LinibangIAiwasKapit.
# ADVERTISEMENTSPASSENGER LISTTRADE RETURNS- SHIPPINGALMANACMETEOROLOGICAL READINGS.
# The Sarawak Gazette.
# THURSDAY, APRIL 4, 1007.
# Birth.
# WADDELLAt Cheriton," Singapore, on the 20th March, the wife of Capt. WADDELL, S. S. Kuching, of a daughter.
# Order.
# No. I, 1907.
# SAILORS signing Articles for a year and working on board Government vessels are not allowed in future to take their discharge or elect substitutes without first makiug application at the Residents Office.
# Certificates of discharge to sailors to be issued only by the Shipping Master.
# See Order August 28th, 1899.
# C. V. BROOKE.
# Rajah Muda.
# Kuching, Sarawak, 31st January, 1907.
# Order.
# No. II, 1907.
# WHERLAS complaint has been made that Gutta Jangka is dicing brought into the market. adulterated with raw sago, clay and other foreign matter.
# I hereby direct that any person or persons found guilty of the adulteration of Gutta Jangka or other jungle produce shall be punished by a fine nnt exceeding $100 or by imprisonment not exceeding six months, and the adulterated produce may be confiscated at the discretion of the Court.
# 17(7c Order re Adulteration of Gutta Jelutong, 15th April, 1902.
# C. V. BROOKE,
# Rajah Muda. Kuching, Sarawak,
# 31st January, 1907.
# Order.
# No. Ill, 1907.
# I HEREBY direct that on and after the 1st proximo the Leper Camp at 5th mile shall be entirely under the superintendence of the Medical Department and not as hitherto of the Police. The Principal Medical Officer or his Deputy will therefore on and after that date be responsible for all arrangements connected with the supply of food for the Camp and will report whenever necessary on matters concerning it to the Honble the Resident 1st Division.
# C. V. BROOKE.
# Rajah Muda. Kuching, Sarawak,
# 13th March, 1907.
# 76
# THE SARAWAK GAZETTE, APRIL 4, 1907.
# Order-
# No. IV, 1907.
# THE following regulations regarding the import of Firearms into Sarawak are published for general information.
# 1 .Any person desirous of importing any Firearm into Sarawak must in first place obtain a 'Permit to do so from Resident's Office in Kuching and after the firearm in question has been imported it will be necessary for the owner to obtain a license to carry same. Europeans or others newly arriving in the Country and bringing in any firearms will have same detained in the Customs Department until production of the necessary Permit."
# 2 .The above mentioned Permits and Licenses are not transferable unless authority has been obtained authorizing the transfer and any person so offending will be liable to a fine not exceeding $ 100.
# 3 .Before importing ammunition it is also necessary to take out a Permit" and the ammunition imported is to be for personal use and not for sale or disposal otherwise except with special permission. The penalty for any iufringment of this regulation will be the same as for unauthorized transfer of firearms.
# By order of His Highness The Rajah Muda.
# P. F. CUNYNGHAME,
# Resident 1st Division. Resident's Ofiice,
# Kuching. Sarawak,
# 23rd March, 1907.
# Notification.
# No. LXIV, 1906.
# No order may contain a fraction of a cent, of
# ft penny or of an anna. Orders on or through**
# the United Kingdom and India should be
# calculated in accordance with the tables
# supplied by the Post Office, and the commis-
# sion added.
# The cheques, accompanied by the special
# printed application form (Outstation Money
# Order application), should be drawn in favour
# of, and forwarded to, the Postmaster General,
# Kuching.
# In the ease of Money Orders (1) on Kuching,
# (2) on or through the United Kingdom and
# (3) on the Strait Settlements, an actual form
# of Money Order is issued for transmission to
# the payee and in order to avoid delay, and
# provided the application is accompanied by a
# fully stamped and addressed envelope, the
# Money Order will bte forwarded to him direct
# by the Kuching Post Office at the remitters
# risk; otherwise it will be sent to the Postal
# Officer applying.
# The envelope may contain the remitters
# advice to the payee but the Post Office accepts
# no responsibility in case of loss and it is ad-
# visable to send it separately.
# In the case of Money Orders on (4) the
# , Federated Malay Statesand (5) on or through
# India no form of Money Order is issued to
# the remitter as the paying offi

# %% [markdown]
# ## 2.2. Split Documents

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap, add_start_index=True)
docs_splits = text_splitter.split_documents(docs)

# %%
# verify documents have been split properly
print("Length:", len(docs_splits))
print("\nExcerpt 1:", docs_splits[10000].page_content)
print("\nExcerpt 2:", docs_splits[10001].page_content)
# Out:
# Length: 23967
#
# Excerpt 1: Forestry.—Forest Ranger Abang Daud reports that various quantities of billian timber have been worked and left in the Krangan area. Notices have been issued that this will be seized and auctioned if the owners do not lay their claims within a specified time limit.
# Travelling.—I left, on the 18th intending to visit the Sea Dyaks in the Ulu Sebangan. At Kepayang however, it was found that there was no water in the river and no path through the jungle. The visit was abandoned and I returned to the station on the 21st.	Marine.—Two experts from the Government Workshop arrived to attend to m.l. Vava. They could not improve matters, however, and the launch was shipped to Kuching for overhaul.
# General.—The Acting Resident, Mr. J. C. Swayne visited the station from the 42th to the 15th, and settled all outstanding matters requiring his attention.	The 24th, being the anniversary of Her Highness the Ranee's birthday, the offices were closed and the flagstaff dressed.
# Two second-hand outboard motors were received on trial from the Agriculture Improvement Fund. It was intended that they should be used by the two outstation Native Officers, but the engines hate not been made to run yet.
#
# Excerpt 2: Two second-hand outboard motors were received on trial from the Agriculture Improvement Fund. It was intended that they should be used by the two outstation Native Officers, but the engines hate not been made to run yet.
# On the 28th I proceeded to Kuching on duty.
# Trade and Shipping.—The new industry—snake skins—proved a useful asset during the month when $1,308.60 was collected in export duty on this item. Some of the Chinese are now making inquiries in Singapore as to possible markets for these skins.
# Sadong Collieries Report. February, 1930. SIGNED BY J. W. EVANS, MANAGER.
# RACE NO. 2. THE SATOK STAKES., Value $150. Second to receive $50. Third to save entrance fee $10. A handicap for Division II ponies. Distance 5 furlongs.
# RACE NO. 3. THE PADUNGAN PLATE. Value $150. Second to receive $50. Third to save entrance fee $10. A handicap for Division in ponies. Distance 6 furlongs.
# RACE NO. 4. THE B.C.L. PLATE. Value $150. $50 subscribed by Messrs. the Borneo Company, Ltd., with $100 added. Second to receive $50. Third to save entrance fee $10. A handicap for Division I ponies. Distance 3 furlongs.

# %% [markdown]
# ## 2.3. Create Embeddings

# %%
gpt4all_embedder = GPT4AllEmbeddings(model_name="all-MiniLM-L6-v2.gguf2.f16.gguf", gpt4all_kwargs={"allow_download": True})

# %%
embeddings = Chroma.from_documents(
    documents=docs_splits,
    embedding=gpt4all_embedder,
    persist_directory=embedding_store_path
)
# because persist_directory is specified, embeddings are automatically saved

# %% [markdown]
# # 3. Use the Model

# %%
# load the saved embedder and get the Chroma database created earlier
# DO NOT run this block if the above block has already been run
gpt4all_embedder = GPT4AllEmbeddings(model_name="all-MiniLM-L6-v2.gguf2.f16.gguf", gpt4all_kwargs={"allow_download": True})
embeddings = Chroma(embedding_function=gpt4all_embedder, persist_directory=embedding_store_path)

# %% [markdown]
# ## 3.1. Context Retriever

# %%
# create the retriver that grabs the most relevant contexts
# "similarity" is cosine similarity
# "k": n means that the n most similar contexts are plucked
retriever = embeddings.as_retriever(search_type="similarity", search_kwargs={"k": chunk_count})

# %%
# verify retriever
retrieved_contexts = retriever.invoke("What events have happened in Limbang?")
print("Contexts:", len(retrieved_contexts))
print("Best Match:", retrieved_contexts[0].page_content)
# Out:
# Contexts: 5
# Best Match: and falsification of books. The Resident, Fourth Division, left Miri on Feb ruary 18th for a tour in the old Fifth Division, returning on the 28th. During the course of this tour he visited Limbang, Lawas, Trusan, Sundar, Brooketon. Brunei and Labuan. Nothing of much importance was brought forward except the difficulty of keeping up Government roads, grounds and buildings on the reduced votes. Limbang Bazaar appeared to be flourishing and full of people and goods, and Lawas Bazaar has built a substantial school. Lawas and Limbang rubber estates are doing well. The District Officer, Limbang and Lawas. reports that Court work was exceedingly light during the month, and no crime of any importance was reported or detected in his district. Very few Dayaks or up-river natives visited Limbang during February, being all busy with their padi-harvests. Reaping was in full swing in both hill and swamp land by the end of the month. The pepper crop was ripening by the end of February and appeared satisfactory, hut it is yet too early to predict the quantity that will be collected. The tapping holiday was conscientiously observed throughout the Limbang district, and only one breach of

# %% [markdown]
# ## 3.2. Prompt Building

# %%
prompt = hub.pull("rlm/rag-prompt")
print(prompt)
# Out:
# input_variables=['context', 'question'] metadata={'lc_hub_owner': 'rlm', 'lc_hub_repo': 'rag-prompt', 'lc_hub_commit_hash': '50442af133e61576e74536c6556cefe1fac147cad032f4377b60c436e6cdcb6e'} messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context', 'question'], template="You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.\nQuestion: {question} \nContext: {context} \nAnswer:"))]

# %%
# load the LLM interface
llm = GPT4All(model=model_name, allow_download=True)

# %%
# while the retriever does return a list of context documents, they need to be concatenated
# into a single str for the LLM, so this function does exactly that
context_sep = "\n\n"
def format_docs(docs):
    # build a list of strs
    context_strs = [doc.page_content for doc in docs]
    # connect everything with context_sep and return it
    return context_sep.join(context_strs)

# this links all of the above into a single chain
rag_chain = (
    # question = user question
    # context = retriever over user question, then use format_docs on the retriever's outputs
    {"context": retriever | format_docs, "question": RunnablePassthrough()}
    # pass both to the prompt, filling it up with the question and context
    | prompt
    # pass the prompt to the LLM
    | llm
    # get the string from the LLM's output
    | StrOutputParser()
)

# %% [markdown]
# ## 3.3. Wrapping Up
# The documentation of LangChain notes that it is possible to add chat history into the application, but this results in two separate calls. Chat history is out-of-scope based on the criteria outlined in the research questions.
#
# Instead, this section will end by the creation of a function for using the chain created above.

# %%
response_sep = " "
def rag(question):
    responses = (chunk for chunk in rag_chain.stream(question))
    response_str = response_sep.join(responses)
    return response_str

# %%
# verify chain
print(rag("What is the current situation of mines in Bau District, August 1948, and what suggestions does Mr. Richards have for them to show a profit?"))
# Out:
#  In August 1948, mines in Bau District were producing gold and showing promise with new developments. The Bidi Gold Mining Company was obtaining actual gold during April 1932, while the Ban Lee Mine had reports of production but showed a Nil Return. Two more mines opened by Ng Kui Hiung and Lee Tung Sen also showed potential for being relatively rich in ores. Mr. Richards suggests that mining companies should make genuine efforts to recommence operations within two years as the Supreme Council resolved upon certain measures, such as remission of rents and continuance of royalty on gold won, to assist the rehabilitation of the mining industry.

# %% [markdown]
# # 4. Evaluation Dataset & Generated Answer Creation
# Section 3 *must* be run before this section!

# %% [markdown]
# ## 4.1. Sarawak Gazette

# %%
text_splitter_qg = RecursiveCharacterTextSplitter(chunk_size=5000, chunk_overlap=300, add_start_index=True)
docs_splits_qg = text_splitter_qg.split_documents(docs)

# %%
# verify documents have been split properly
len(docs_splits_qg)
# Out:
# 4656

# %%
# get 100 random chunks
random.seed(random_seed) # needed for reproducible results
indexes_to_retrieve = random.sample(range(len(docs_splits_qg)), 120) # an extra 20 is specified here as some chunks might be dirty
contexts = [docs_splits_qg[i].page_content + '\n\n[NEXT EXCERPT]\n\n' for i in indexes_to_retrieve]

# %%
# write the contexts into a file, unfortunately the contexts must be checked manually
with open(question_contexts_filepath, 'w', encoding='utf-8') as question_contexts_file:
    question_contexts_file.writelines(contexts)

# %% [markdown]
# ## 4.2. Subset of ChroniclingAmericaQA

# %%
# load JSON
with open(caqa_filepath, encoding="utf-8") as testing_file:
    caqa_json = json.load(testing_file)
print(len(caqa_json))
print(caqa_json[0])
# Out:
# 24084
# {'question': 'How many lots did Thomas Peirce have?', 'answer': '183', 'org_answer': '183', 'para_id': 'New Hampshire_18030125_16', 'context': 'Axivil Roberts, part of lot 180 108 60 Capt. George Walker, 181 140 35 George Townson, 183 48 19 Samuel Snell, 184 36 9 Samuel Waterhouse, 185 24 6 John Parker, 186 36 10 John Davis, 187 45 20 John Cross, 188 15 4 Benjamin Cross, 189 50 13 Widow Gilman, 209 21 8 George Peirce, 209 200 75 Thomas Peirce, 220 185 71 SIXTH RANGE: Col. Henry Sherburne, 241 552 150 Nathaniel Roberts, 249 30 8 Jonathan Patridge, 252 60 18 John Sherburne’s widow, 253 24 7 Edward Wells, 254 120 50 John Collins, 272 60 90 Joseph Simpson, part lot 293 40 12 Abraham Senter, 276 68 24 John Cotton’s children, 278 30 60 Francis Devere, 270 60 23 The hundred acre lots: Ephraim Jackman, part of 6 65 5 Nathaniel Mendum, 13 65 35 Joshua Peirce, 87 105 35 Mark Wentworth, Esq. 38 105 35 Nathaniel Peverly, 49 5 8 James Gray, 41 105 85 The fifty acre lots: Jonathan Hanson, 50 50 The two mile street: M. Wentworth, Esq. part of 280 179 Edward Hill, 30 5 George Hill, 10 5 Isaac Williams, 90 10 John Williams, 20 10 JOSHUA OTIS, Coll’r. Barrington, Jan. 7, 1803. FOR SAVANNAH, THE Schooner Fox- Ridley, burthen, now lying at Capt. Nath’l Melcher’s Wharf, will sail in ten days, having nearly all her Freight engaged,—for Freight or Passage apply to NATHANIEL GUNNISON. Portsmouth, January 11, 1803.', 'publication_date': '18030125', 'trans_que': '0', 'trans_ans': '0'}

# %%
# choose only n out of 24084 examples
random.seed(random_seed)
indexes_to_retrieve = random.sample(range(len(caqa_json)), caqa_max)
caqa_dataset = []
for i in indexes_to_retrieve:
    example = caqa_json[i]
    caqa_dataset.append({
        "context": example["context"],
        "question": example["question"],
        "answer": example["answer"]
    })
print(len(caqa_dataset))
print(caqa_dataset[0])
# Out:
# 500
# {'context': 'If IMIE uodcuigtinl KxAii.i urs appointed by JL County Commissioners for Hurt turd county, will meet on the ground, On THURSDAY, February 11th, 1868. At 10 o\'clock, A. M., to ascertain and determine whether the public convenience requires a public road to be opened, commencing near Ruff\'s Mill, and passing through the heads of Samuel M. Magraw, Thomas Sutton and Thomas Hendon, to intersect, at a convenient point, the road leading from Schuck’s to Bull\'s Shops. WM T. CLARK, WM. MECHEM. R. JOHN ROUSS. janS Examiners. CARRIAGE AND TIRE BOLTS, AXLE CLIPS, And Cushion Buttons, Carriage Oil Cloths, Linings, PrinuftS In stock of MOORE & NORRIS, novii ltd Ar, Md. Im have selling; ptxfililLg )o\\ Utr-M [r\'V A. Hln .1., Willi apl. Harne, I <.. Kew Y.irk. - F CMIKTIUNI, NEW AND I\'IlEMI.- A \\. ■ I■, T„ £• ‘H, WM.AE MUSIC t POrutAß |MUC>;g. ‘ IlilrhciHk S Hcll-UiuihSurii\'aai Mmir Ir.rthf Mi 11;,,,, " uTA^v m, i. v^ ,ll “l ”f 111.- r,.i,ii,- s,. ,ir CAPTAIN JINKS OF THE HORSE MARINES • s••>■* t follow rojiAiiv. p.i. 5 NowoU-hIo, hm> It or will acl It j„„. Maill on • oi ll l of price. Ad.li-ffi HEN.I, W. H TCIIWX’K Pub- Imlior, Ml) Spring rlrert, New York. TO THE WORKING CLASS. I AM now prepared to furnish constant employment to ...I .■I. < Mtil.uir laborers) for their spur.', 'question': 'Along with Samuel M. Magraw, Thomas Hendon and Thomas Hendon, who passed through the heads of Samuel M. Magraw?', 'answer': 'Thomas Sutton'}

# %%
# save as new JSON file
with open(caqa_subset_filepath, 'w', encoding='utf-8') as caqa_subset_file:
    json.dump(caqa_dataset, caqa_subset_file, indent=4)

# %% [markdown]
# ## 4.3. Generated Answers for Sarawak Gazette

# %%
# load up the questions
questions = []
with open(reference_answers_filepath, encoding="utf-8") as testing_file:
    for line in testing_file:
        if line.startswith("Q: "):
            questions.append(line[3:])

# %%
# verify questions are properly loaded
print("Questions:", len(questions))
# Out:
# Questions: 100

# %%
# feed the questions into the LLM to get the generated answers, and save after each generated answer
file_path = Path(generated_answers_path)
test_subset_saga = test_subset["saga"]
question_subset = questions[(test_subset_saga[0]-1):test_subset_saga[1]]
questions_len = len(question_subset)
start_time_ns = perf_counter_ns()
print("Questions to generate answers for:", questions_len)
print("({} to {})".format(test_subset_saga[0], test_subset_saga[1]))

for index, question in enumerate(question_subset):
    print("Generating answer for question \"", question, "\"...")
    generated_answer = rag(question)
    
    with open(file_path / "saga" / (str(index + test_subset_saga[0]) + '.txt'), 'w', encoding='utf-8') as generated_answer_file:
        generated_answer_file.write(generated_answer)
    
    print("Done. Questions Left:", questions_len - index - 1)
    time_elapsed_ns = perf_counter_ns() - start_time_ns
    time_estimated_ns = time_elapsed_ns / (index + 1) * (questions_len - (index + 1))
    print("Minutes Left: {:.2f}".format(time_estimated_ns / 6e10))
# Out:
# Questions to generate answers for: 100
# (1 to 100)
# Generating answer for question " What was the reason for issuing notices prohibiting strangers from collecting fruit in certain Dyak areas?
#  "...
# Done. Questions Left: 99
# Minutes Left: 213.95
# Generating answer for question " Who visited Saratok on June 14th, 1933?
#  "...
# Done. Questions Left: 98
# Minutes Left: 214.92
# Generating answer for question " What was the cause of the stampede among the cattle in Simanggang?
#  "...
# Done. Questions Left: 97
# Minutes Left: 212.98
# Generating answer for question " What were some of the events that occurred in Balingian during May 1927?
#  "...
# Done. Questions Left: 96
# Minutes Left: 212.13
# Generating answer for question " What were some of the challenges faced by passengers during their journey from Hong Kong to Swatow in 1927?
#  "...
# Done. Questions Left: 95
# Minutes Left: 212.59
# Generating answer for question " What were some of the challenges faced by communities living near rivers such as Simunjan and Gedong during this time period?
#  "...
# Done. Questions Left: 94
# Minutes Left: 210.82
# Generating answer for question " What were some of the potential consequences of natural population increase on Johore's west coast, and what was suggested as an alternative solution for Malay settlement?
#  "...
# Done. Questions Left: 93
# Minutes Left: 203.02
# Generating answer for question " What was the main reason for opening up the Land Office in Sarikei?
#  "...
# Done. Questions Left: 92
# Minutes Left: 201.94
# Generating answer for question " What events led up to Charles Brooke's intervention in Sadong district?
#  "...
# Done. Questions Left: 91
# Minutes Left: 198.15
# Generating answer for question " What events took place in Sibu during the period covered by Mr. E. V. Andreini's report?
#  "...
# Done. Questions Left: 90
# Minutes Left: 201.50
# Generating answer for question " What is the significance of the Sea Dyak language in relation to other languages?
#  "...
# Done. Questions Left: 89
# Minutes Left: 203.08
# Generating answer for question " In the passage "The Man Who Could Work Miracles," what is mentioned about H. G. Wells' delightful story?
#  "...
# Done. Questions Left: 88
# Minutes Left: 208.58
# Generating answer for question " What are some of the sections that were featured in the Malaya Borneo Exhibition?
#  "...
# Done. Questions Left: 87
# Minutes Left: 211.52
# Generating answer for question " What is the purpose of establishing Central Banks and Co-operative Rural Credit movement according to the passage?
#  "...
# Done. Questions Left: 86
# Minutes Left: 208.23
# Generating answer for question " What were some of the tasks performed by Mr. C. G. Dun during his visit to Tebakang as mentioned in the passage?
#  "...
# Done. Questions Left: 85
# Minutes Left: 211.23
# Generating answer for question " Who was Cyril Joad and what was his significance in England during the 1940s?
#  "...
# Done. Questions Left: 84
# Minutes Left: 213.21
# Generating answer for question " What concerns were raised about the Sarawak Library membership fees and what suggestion was made by "Casual" regarding non-members visiting the library?
#  "...
# Done. Questions Left: 83
# Minutes Left: 214.45
# Generating answer for question " What was discussed in the Annual General Meeting of Borneo Company Limited?
#  "...
# Done. Questions Left: 82
# Minutes Left: 215.79
# Generating answer for question " What information does Walter K. Witt provide about Tom Harrisson's talk on the Kelabits?
#  "...
# Done. Questions Left: 81
# Minutes Left: 211.30
# Generating answer for question " What was the reason for detaining Juak, a Dyak who is insane?
#  "...
# Done. Questions Left: 80
# Minutes Left: 210.32
# Generating answer for question " What events took place in Bintulu during February 1930?
#  "...
# Done. Questions Left: 79
# Minutes Left: 209.15
# Generating answer for question " What events took place during Race Week in Sarawak?
#  "...
# Done. Questions Left: 78
# Minutes Left: 209.19
# Generating answer for question " What was the main focus of the District Officer's time during his stay in Matu and Daro on October and November 1919?
#  "...
# Done. Questions Left: 77
# Minutes Left: 209.15
# Generating answer for question " Who were present at the Annual Prize Giving event for Kuching Malay Vernacular Schools?
#  "...
# Done. Questions Left: 76
# Minutes Left: 207.95
# Generating answer for question " What was Her Highness the Ranee Margaret's background before she married His Highness the Rajah?
#  "...
# Done. Questions Left: 75
# Minutes Left: 206.39
# Generating answer for question " What were some of the events that took place during His Excellency the Governor's visit to Lawas?
#  "...
# Done. Questions Left: 74
# Minutes Left: 203.82
# Generating answer for question " What was the outcome of the Court's decision regarding Lord Rothermere?
#  "...
# Done. Questions Left: 73
# Minutes Left: 199.38
# Generating answer for question " What was the reason behind Dr. Su Chin Nang's farewell speech at the dinner party recently given by him at Sibu?
#  "...
# Done. Questions Left: 72
# Minutes Left: 196.92
# Generating answer for question " Who paid a visit to Miri along with Mr. Boult the Chief Secretary on July 16th, 1930?
#  "...
# Done. Questions Left: 71
# Minutes Left: 193.88
# Generating answer for question " What is the significance of air strips in the Fourth Division?
#  "...
# Done. Questions Left: 70
# Minutes Left: 190.18
# Generating answer for question " What type of fishing methods will be tested by the "Tongkol," the experimental fisheries vessel built for the Straits Settlements Government?
#  "...
# Done. Questions Left: 69
# Minutes Left: 187.66
# Generating answer for question " What concerns or issues does Mr. Harrisson have with Mr. Leach's letter?
#  "...
# Done. Questions Left: 68
# Minutes Left: 182.88
# Generating answer for question " What was the reason behind prohibiting tuba fishing in certain rivers?
#  "...
# Done. Questions Left: 67
# Minutes Left: 180.04
# Generating answer for question " What were some of the events that took place during Mr. Arundell's visit in Simanggang?
#  "...
# Done. Questions Left: 66
# Minutes Left: 178.95
# Generating answer for question " What are some activities that can be done around West Lake in Hangzhou?
#  "...
# Done. Questions Left: 65
# Minutes Left: 176.44
# Generating answer for question " What is the news about Mr. W. Cotterill and Mr. A. Macpherson in The Sarawak Gazette dated January 3, 1927?
#  "...
# Done. Questions Left: 64
# Minutes Left: 173.41
# Generating answer for question " What was guaranteed under the New South Wales Pure Food Act in relation to "Alexandria" canned meats?
#  "...
# Done. Questions Left: 63
# Minutes Left: 167.12
# Generating answer for question " What information did the District Officer, Miri provide about land disputes among Dayaks and their impact on Cession discussions?
#  "...
# Done. Questions Left: 62
# Minutes Left: 164.56
# Generating answer for question " What were some of the main issues that Norman MacPhee faced during his time as Resident of Lower Rejang in 1906?
#  "...
# Done. Questions Left: 61
# Minutes Left: 162.23
# Generating answer for question " What was the reason for Pangeran Haji Mohamad demanding tax from the Dayaks of Ridan?
#  "...
# Done. Questions Left: 60
# Minutes Left: 160.75
# Generating answer for question " What was the reason behind the decision of registering all bicycles in the municipality?
#  "...
# Done. Questions Left: 59
# Minutes Left: 158.06
# Generating answer for question " What event led Norman MacPhee to visit the Kayans and Kenyahs living in the Tutau and Apoh Rivers?
#  "...
# Done. Questions Left: 58
# Minutes Left: 155.58
# Generating answer for question " What is the origin of petroleum according to the text?
#  "...
# Done. Questions Left: 57
# Minutes Left: 153.47
# Generating answer for question " What are two solutions to avoid spoiling chicken in Sarawak?
#  "...
# Done. Questions Left: 56
# Minutes Left: 151.28
# Generating answer for question " What is the purpose of the special performance of pictures in the Globe Picture Theatre on 9th November 1931?
#  "...
# Done. Questions Left: 55
# Minutes Left: 148.01
# Generating answer for question " Who was granted a pension one year before passing away in 7 July 1927?
#  "...
# Done. Questions Left: 54
# Minutes Left: 146.04
# Generating answer for question " What were some of the main tasks carried out by the Acting Assistant District Officer in Sarikei and Binatang?
#  "...
# Done. Questions Left: 53
# Minutes Left: 143.62
# Generating answer for question " What happened to Bong Tze when he was caught with opium?
#  "...
# Done. Questions Left: 52
# Minutes Left: 141.94
# Generating answer for question " What is the reason for closing Government offices on February 24th?
#  "...
# Done. Questions Left: 51
# Minutes Left: 139.85
# Generating answer for question " What was the main purpose of the Kuching Annual Agricultural Show?
#  "...
# Done. Questions Left: 50
# Minutes Left: 137.14
# Generating answer for question " What was the reason behind some Dyaks above Muput wishing for Ngumbang to be appointed as Penghulu instead of Pu. Bunya?
#  "...
# Done. Questions Left: 49
# Minutes Left: 134.15
# Generating answer for question " What was the punishment given to Ragus and how many sections did it cover?
#  "...
# Done. Questions Left: 48
# Minutes Left: 131.74
# Generating answer for question " What are the prizes being offered for exhibits illustrating novel uses of rubber?
#  "...
# Done. Questions Left: 47
# Minutes Left: 128.90
# Generating answer for question " What was the purpose of the Sarawak Agricultural Development Board and how often were meetings held initially?
#  "...
# Done. Questions Left: 46
# Minutes Left: 125.92
# Generating answer for question " What role did Jim Hoover play in introducing modern machinery to Borneo?
#  "...
# Done. Questions Left: 45
# Minutes Left: 123.19
# Generating answer for question " What is mentioned about the condition and future plans for the Dalat road, Bakong-Trus road, and other Oya roads?
#  "...
# Done. Questions Left: 44
# Minutes Left: 120.32
# Generating answer for question " What is the graded scale used by Malay workers to value different colors and what does a high proportion of yellow in shell indicate?
#  "...
# Done. Questions Left: 43
# Minutes Left: 115.89
# Generating answer for question " What were the subsidiary crops seen in the Bugis concession at Jaie during the inspection on July 18th, 1930?
#  "...
# Done. Questions Left: 42
# Minutes Left: 113.46
# Generating answer for question " What was the outcome of the Mukah Agricultural Show in terms of encouraging agricultural pursuits and native industries?
#  "...
# Done. Questions Left: 41
# Minutes Left: 110.91
# Generating answer for question " What is Evelyn Van Pippen's unique characteristic that involves her tongue?
#  "...
# Done. Questions Left: 40
# Minutes Left: 108.24
# Generating answer for question " What measures did the Food Control Department take to ensure rice supply during the month, and how did the native population react?
#  "...
# Done. Questions Left: 39
# Minutes Left: 105.53
# Generating answer for question " What were some notable positions held by His Excellency J. L. Humphreys before becoming Governor of North Borneo?
#  "...
# Done. Questions Left: 38
# Minutes Left: 102.96
# Generating answer for question " What was Mary Hoover's significant contribution to Sarawak and how did her influence impact the community?
#  "...
# Done. Questions Left: 37
# Minutes Left: 100.34
# Generating answer for question " What happened to Chan Seo Seug, the young Chinese bicyclist?
#  "...
# Done. Questions Left: 36
# Minutes Left: 97.65
# Generating answer for question " What factors could have contributed to the decline of cricket's popularity among non-European communities in Kuching?
#  "...
# Done. Questions Left: 35
# Minutes Left: 95.01
# Generating answer for question " What was the process used at Sabulan, Bau for extracting gold and how does it differ from what "old stagers" might be familiar with?
#  "...
# Done. Questions Left: 34
# Minutes Left: 92.51
# Generating answer for question " What does "Adversity" offer as a solution for those who struggle with manual skills during hard times?
#  "...
# Done. Questions Left: 33
# Minutes Left: 89.68
# Generating answer for question " What was the reason for Rev. W. G. Illingworth leaving Saribas?
#  "...
# Done. Questions Left: 32
# Minutes Left: 86.90
# Generating answer for question " What are the two joint schemes approved with North Borneo and Brunei?
#  "...
# Done. Questions Left: 31
# Minutes Left: 83.98
# Generating answer for question " What does "Public Nuisance" refer to?
#  "...
# Done. Questions Left: 30
# Minutes Left: 81.16
# Generating answer for question " What was Mr. Poggy's experience working at the sago plantations in Simanggang?
#  "...
# Done. Questions Left: 29
# Minutes Left: 78.71
# Generating answer for question " What did Red Riding Hood find unusual about the wolf's vocal organ in their conversation?
#  "...
# Done. Questions Left: 28
# Minutes Left: 76.01
# Generating answer for question " What does Mr. Wade argue about determining facts in a native criminal case, and how do financial considerations affect this issue?
#  "...
# Done. Questions Left: 27
# Minutes Left: 73.18
# Generating answer for question " What were some of the actions taken by J.C. Swayne during his time as Resident Second Class in Lawas?
#  "...
# Done. Questions Left: 26
# Minutes Left: 70.52
# Generating answer for question " What is the current situation of mines in Bau District, August 1948, and what suggestions does Mr. Richards have for them to show a profit?
#  "...
# Done. Questions Left: 25
# Minutes Left: 68.02
# Generating answer for question " What caused the destruction of the unoccupied storekeeper's bungalow and burial of the Main Railway Line in December, 1931?
#  "...
# Done. Questions Left: 24
# Minutes Left: 65.45
# Generating answer for question " What were some observations made during the trip to Simatan and Poi Mountain on 23 June 1930?
#  "...
# Done. Questions Left: 23
# Minutes Left: 62.78
# Generating answer for question " What was the reason for not having a competent court to entertain an appeal in Ellin Anak Masing v. The King case?
#  "...
# Done. Questions Left: 22
# Minutes Left: 60.12
# Generating answer for question " What is the opinion on the dietary habits of different countries mentioned in the texts dated 1 September 1927?
#  "...
# Done. Questions Left: 21
# Minutes Left: 57.36
# Generating answer for question " What were some differences between transportation methods in Kuching around 1912 compared to today?
#  "...
# Done. Questions Left: 20
# Minutes Left: 54.55
# Generating answer for question " What were the main concerns discussed during the meeting of Tuais, particularly regarding Dyaks working in Netherlands Borneo?
#  "...
# Done. Questions Left: 19
# Minutes Left: 51.92
# Generating answer for question " What were the recommendations made to the Chiefs of the Tua Tua Kampong in regards to their role in hearing cases?
#  "...
# Done. Questions Left: 18
# Minutes Left: 49.21
# Generating answer for question " What were the challenges faced by E. R. Stilwell in finding labor for clearing roads?
#  "...
# Done. Questions Left: 17
# Minutes Left: 46.34
# Generating answer for question " What is the definition of "quasi-marital relation"?
#  "...
# Done. Questions Left: 16
# Minutes Left: 43.70
# Generating answer for question " What is the relationship between the Bisaya language and other languages in North Borneo and Brunei?
#  "...
# Done. Questions Left: 15
# Minutes Left: 40.94
# Generating answer for question " What was the outcome of Choo Poi's appeal against his decision in District Court for obstructing a public servant?
#  "...
# Done. Questions Left: 14
# Minutes Left: 38.30
# Generating answer for question " What was Dr. G. E. Brooke's contribution to Sarawak during his stay there?
#  "...
# Done. Questions Left: 13
# Minutes Left: 35.57
# Generating answer for question " Who was the oldest landmark of the British Community in Labuan?
#  "...
# Done. Questions Left: 12
# Minutes Left: 32.83
# Generating answer for question " What measures were taken regarding jelutong permits in November 1919?
#  "...
# Done. Questions Left: 11
# Minutes Left: 30.20
# Generating answer for question " What led to the disagreement between the Army Airmen and Naval Air Service over uniform colors?
#  "...
# Done. Questions Left: 10
# Minutes Left: 27.48
# Generating answer for question " What is the new postal rate for Sarawak letters as of October 1st, 1907?
#  "...
# Done. Questions Left: 9
# Minutes Left: 24.79
# Generating answer for question " What happened on March 1st, 1919 regarding S.S. Gladys and who were the passengers on S.S. Gladys?
#  "...
# Done. Questions Left: 8
# Minutes Left: 22.05
# Generating answer for question " What change was expected to occur in the Kuching telephone system on April 1st, 1947?
#  "...
# Done. Questions Left: 7
# Minutes Left: 19.32
# Generating answer for question " What was the impact of the floods on Oya and Dalat in January 1932?
#  "...
# Done. Questions Left: 6
# Minutes Left: 16.57
# Generating answer for question " What were the records lowered during the Sarawak Turf Club meeting concluded on 24th, 26th and 28th of April, 1937?
#  "...
# Done. Questions Left: 5
# Minutes Left: 13.84
# Generating answer for question " What was the main reason behind the success of "Mixed Grill" performed by Miri Amateur Dramatic Society?
#  "...
# Done. Questions Left: 4
# Minutes Left: 11.04
# Generating answer for question " What was the event held for Admiral and Lady Little during their visit to Kuching?
#  "...
# Done. Questions Left: 3
# Minutes Left: 8.28
# Generating answer for question " What were some of the issues faced by the Dyaks mentioned in the texts dated 1 June 1927?
#  "...
# Done. Questions Left: 2
# Minutes Left: 5.51
# Generating answer for question " What were some key events and actions that took place during Mr. E. V. Andreini's visit in Sarawak as reported by him?
#  "...
# Done. Questions Left: 1
# Minutes Left: 2.75
# Generating answer for question " What significant event did the Chinese community in Kuching celebrate on September 3rd?
#  "...
# Done. Questions Left: 0
# Minutes Left: 0.00

# %% [markdown]
# ## 4.4. Generated Answers for Subset of ChroniclingAmericaQA

# %%
# load JSON
with open(caqa_subset_filepath, encoding="utf-8") as testing_file:
    caqa_dataset = json.load(testing_file)
print(len(caqa_dataset))
print(caqa_dataset[0])
# Out:
# 500
# {'context': 'If IMIE uodcuigtinl KxAii.i urs appointed by JL County Commissioners for Hurt turd county, will meet on the ground, On THURSDAY, February 11th, 1868. At 10 o\'clock, A. M., to ascertain and determine whether the public convenience requires a public road to be opened, commencing near Ruff\'s Mill, and passing through the heads of Samuel M. Magraw, Thomas Sutton and Thomas Hendon, to intersect, at a convenient point, the road leading from Schuck’s to Bull\'s Shops. WM T. CLARK, WM. MECHEM. R. JOHN ROUSS. janS Examiners. CARRIAGE AND TIRE BOLTS, AXLE CLIPS, And Cushion Buttons, Carriage Oil Cloths, Linings, PrinuftS In stock of MOORE & NORRIS, novii ltd Ar, Md. Im have selling; ptxfililLg )o\\ Utr-M [r\'V A. Hln .1., Willi apl. Harne, I <.. Kew Y.irk. - F CMIKTIUNI, NEW AND I\'IlEMI.- A \\. ■ I■, T„ £• ‘H, WM.AE MUSIC t POrutAß |MUC>;g. ‘ IlilrhciHk S Hcll-UiuihSurii\'aai Mmir Ir.rthf Mi 11;,,,, " uTA^v m, i. v^ ,ll “l ”f 111.- r,.i,ii,- s,. ,ir CAPTAIN JINKS OF THE HORSE MARINES • s••>■* t follow rojiAiiv. p.i. 5 NowoU-hIo, hm> It or will acl It j„„. Maill on • oi ll l of price. Ad.li-ffi HEN.I, W. H TCIIWX’K Pub- Imlior, Ml) Spring rlrert, New York. TO THE WORKING CLASS. I AM now prepared to furnish constant employment to ...I .■I. < Mtil.uir laborers) for their spur.', 'question': 'Along with Samuel M. Magraw, Thomas Hendon and Thomas Hendon, who passed through the heads of Samuel M. Magraw?', 'answer': 'Thomas Sutton'}

# %%
# make a new chain since the retriever is not used
caqa_eval_rag_chain = (
    RunnablePassthrough()
    | prompt
    | llm
    | StrOutputParser()
)

# %%
# make a new function that passes the input to the llm
response_sep = " "
def caqa_eval_rag(example):
    question_and_context = {"question": example["question"], "context": example["context"]}
    responses = (chunk for chunk in caqa_eval_rag_chain.stream(question_and_context))
    response_str = response_sep.join(responses)
    return response_str

# %%
# verify chain
print("Generated Answer:", caqa_eval_rag(caqa_dataset[0]))
# Out:
# Generated Answer:  The heads of Thomas Hendon were passed through by a road that was being considered for opening, commencing near Ruff's Mill and intersecting at a convenient point with the road leading from Schuck’s to Bull's Shops.

# %%
# feed the questions into the LLM to get the generated answers, and save after each generated answer
file_path = Path(generated_answers_path)
test_subset_caqa = test_subset["caqa"]
caqa_subset = caqa_dataset[(test_subset_caqa[0]-1):test_subset_caqa[1]]
caqa_subset_len = len(caqa_subset)
start_time_ns = perf_counter_ns()
print("Questions to generate answers for:", caqa_subset_len)
print("({} to {})".format(test_subset_caqa[0], test_subset_caqa[1]))

for index, example in enumerate(caqa_subset):
    print("Generating answer for question \"", example["question"], "\"...")
    generated_answer = caqa_eval_rag(example)
    
    with open(file_path / "caqa" / (str(index + test_subset_caqa[0]) + '.txt'), 'w', encoding='utf-8') as generated_answer_file:
        generated_answer_file.write(generated_answer)
    
    print("Done. Questions Left:", caqa_subset_len - index - 1)
    time_elapsed_ns = perf_counter_ns() - start_time_ns
    time_estimated_ns = time_elapsed_ns / (index + 1) * (caqa_subset_len - (index + 1))
    print("Minutes Left: {:.2f}".format(time_estimated_ns / 6e10))
# Out:
# Questions to generate answers for: 500
# (1 to 500)
# Generating answer for question " Along with Samuel M. Magraw, Thomas Hendon and Thomas Hendon, who passed through the heads of Samuel M. Magraw? "...
# Done. Questions Left: 499
# Minutes Left: 509.28
# Generating answer for question " When was the Masonic Temple Bonds Office Masonic Trust established? "...
# Done. Questions Left: 498
# Minutes Left: 448.64
# Generating answer for question " Who was the Judge of the Supreme Court? "...
# Done. Questions Left: 497
# Minutes Left: 440.56
# Generating answer for question " Along with Louisiana, Missouri, Iowa, and Minnesota, what state has a portion west of the Mississippi River? "...
# Done. Questions Left: 496
# Minutes Left: 410.67
# Generating answer for question " How often is wheat sold in Chicago? "...
# Done. Questions Left: 495
# Generating answer for question " Who was the Corresponding Secretary of the A.C. Society? "...
# Done. Questions Left: 443
# Minutes Left: 304.42
# Generating answer for question " Along with Choctaw, what club gave the last dance of the season? "...
# Done. Questions Left: 442
# Minutes Left: 302.11
# Generating answer for question " Along with Graxe's, Troy, Fa,tional and Persigny, what other company makes Paper Collars? "...
# Done. Questions Left: 441
# Minutes Left: 301.26
# Generating answer for question " Who is the second vice president of the Rotary club? "...
# Done. Questions Left: 440
# Minutes Left: 299.84
# Generating answer for question " How much did Stanley's soul dare to form? "...
# Done. Questions Left: 439
# Minutes Left: 297.01
# Generating answer for question " Who blocked the coasts of Mexico and Buenos Aires? "...
# Done. Questions Left: 438
# Minutes Left: 295.41
# Generating answer for question " How many Indians were rescued from the Santa Barbara mission? "...
# Done. Questions Left: 437
# Minutes Left: 293.81
# Generating answer for question " How long has Almon Ticknor been a teacher? "...
# Done. Questions Left: 436
# Minutes Left: 292.55
# Generating answer for question " How much did the Postmaster General spend for mail depredations and special agents? "...
# Done. Questions Left: 435
# Minutes Left: 289.96
# Generating answer for question " Who sent two gentlemen to communicate with the English Government on the question of the Belgian fortresses? "...
# Done. Questions Left: 434
# Minutes Left: 288.00
# Generating answer for question " Who left the first of the week for a visit with her sister, Mrs. Kloster? "...
# Done. Questions Left: 433
# Minutes Left: 286.37
# Generating answer for question " Who is collecting two car loads of Dakota for exhibitions at eastern fairs? "...
# Done. Questions Left: 432
# Minutes Left: 285.05
# Generating answer for question " Which country gets the profits from American vessels by revoking countervailing laws? "...
# Done. Questions Left: 431
# Minutes Left: 283.52
# Generating answer for question " During what season are the improvements on the LAND in the State of New York? "...
# Done. Questions Left: 430
# Minutes Left: 283.18
# Generating answer for question " How many of the firm asked Frank to support the Whig ticket? "...
# Done. Questions Left: 429
# Minutes Left: 281.80
# Generating answer for question " What is the name of Golden Spe- cific Co.? "...
# Done. Questions Left: 428
# Minutes Left: 281.13
# Generating answer for question " How many lines of advertisements are at 5 cents per line? "...
# Done. Questions Left: 427
# Minutes Left: 279.72
# Generating answer for question " What empire is likely to be partitioned by France? "...
# Done. Questions Left: 426
# Minutes Left: 278.16
# Generating answer for question " Who obtained leave and brought in a bill relating to the Fort lands? "...
# Done. Questions Left: 425
# Minutes Left: 276.76
# Generating answer for question " How many people viewed the grapevine at the centennial exposition in Philadelphia? "...
# Done. Questions Left: 424
# Minutes Left: 277.50
# Generating answer for question " How many Cherry st. does E. LAMBERT & CO. have for sale? "...
# Done. Questions Left: 423
# Minutes Left: 277.34
# Generating answer for question " What state's troops is William Sulzer commanding? "...
# Done. Questions Left: 422
# Minutes Left: 277.57
# Generating answer for question " Along with Warren, Jefferson, and Clinton, who made envy and foul malice nourishment, dare bite the host? "...
# Done. Questions Left: 421
# Minutes Left: 276.80
# Generating answer for question " How many girls were in the House of Refuge? "...
# Done. Questions Left: 420
# Minutes Left: 275.93
# Generating answer for question " Along with Georgia and Florida, what state received a dispatch from Washington? "...
# Done. Questions Left: 419
# Minutes Left: 274.81
# Generating answer for question " Who is the tallest man in New York? "...
# Minutes Left: 242.71
# Generating answer for question " How many Mussulmen did the general levy of all Mussulmen from 14 to? "...
# Done. Questions Left: 366
# Minutes Left: 242.15
# Generating answer for question " On what day did the Charles Morgan load "independent"? "...
# Done. Questions Left: 365
# Minutes Left: 241.14
# Generating answer for question " Truro Crane and John P. Meakin are the only genuine three-ring circus of what party? "...
# Done. Questions Left: 364
# Minutes Left: 240.11
# Generating answer for question " How many gallons does one gallon of U.S. DIP. WASH AND DISINFECTANT make? "...
# Done. Questions Left: 363
# Minutes Left: 239.75
# Generating answer for question " Along with North Carolina, what state is known as the "Rocky Mountain Gold Sin"? "...
# Done. Questions Left: 362
# Minutes Left: 238.56
# Generating answer for question " How many casks of Missouri Ribbed Sides were sold for Bacon? "...
# Done. Questions Left: 361
# Minutes Left: 238.67
# Generating answer for question " What group did Capt. Brown fear would attack all the points on the Rio Grande? "...
# Done. Questions Left: 360
# Minutes Left: 237.93
# Generating answer for question " What city did Capt. Brown say the British had been besieging for 14 days prior to his sailing? "...
# Done. Questions Left: 359
# Minutes Left: 237.32
# Generating answer for question " How many straight wins did Omaha have against Denver? "...
# Done. Questions Left: 358
# Minutes Left: 237.66
# Generating answer for question " Along with Utah, in what state was slavery prohibited by an act of Congress? "...
# Done. Questions Left: 357
# Minutes Left: 236.85
# Generating answer for question " What country does Don Pedro's daughter Donna Maria reside in? "...
# Done. Questions Left: 356
# Minutes Left: 236.37
# Generating answer for question " Who was Henry Clay Pinckney's mistress? "...
# Done. Questions Left: 355
# Minutes Left: 235.69
# Generating answer for question " How tall is the dam across the Fox River at Burlington? "...
# Done. Questions Left: 354
# Minutes Left: 234.84
# Generating answer for question " What country is in a muddle with Italy? "...
# Done. Questions Left: 353
# Minutes Left: 234.01
# Generating answer for question " How many children did the wife of General Rostenstin have? "...
# Done. Questions Left: 352
# Minutes Left: 233.21
# Generating answer for question " The church of the Transfiguration was unsafe in what city? "...
# Done. Questions Left: 351
# Minutes Left: 232.29
# Generating answer for question " Which party had a majority on the Supreme bench? "...
# Done. Questions Left: 350
# Minutes Left: 231.01
# Generating answer for question " What was the title of Louis Charles? "...
# Done. Questions Left: 349
# Minutes Left: 230.38
# Generating answer for question " How many volumes does the Edinburgh Gazette fill? "...
# Done. Questions Left: 348
# Minutes Left: 229.51
# Generating answer for question " How long before Franklin's death did he declare he had never used tobacco? "...
# Done. Questions Left: 347
# Minutes Left: 228.48
# Generating answer for question " When will the chapter houses of Amherst's fraternity system close? "...
# Done. Questions Left: 346
# Minutes Left: 227.76
# Generating answer for question " Two suits for damages have recently come off in what state? "...
# Done. Questions Left: 345
# Minutes Left: 227.10
# Generating answer for question " When did the US frigate John Adams sail from Cherbourg? "...
# Done. Questions Left: 344
# Minutes Left: 226.30
# Generating answer for question " How many P.M. are local to Portland? "...
# Done. Questions Left: 343
# Minutes Left: 226.30
# Generating answer for question " When does the fiscal year of the school board begin? "...
# Done. Questions Left: 342
# Minutes Left: 225.76
# Generating answer for question " What language were the scriptures in the Septuagint written in? "...
# Minutes Left: 208.74
# Generating answer for question " When did Nome's output equal that of 1916? "...
# Done. Questions Left: 315
# Minutes Left: 207.85
# Generating answer for question " Along with France, Flanders, Germany, and Spain, what country is at war with the United States? "...
# Done. Questions Left: 314
# Minutes Left: 207.04
# Generating answer for question " What is the fairest price for wool in Ohio XX? "...
# Done. Questions Left: 313
# Minutes Left: 206.20
# Generating answer for question " How many squares are in Union Station? "...
# Done. Questions Left: 312
# Minutes Left: 205.51
# Generating answer for question " How many questions did the opposing counsel ask before Goff and the jury? "...
# Done. Questions Left: 311
# Minutes Left: 204.77
# Generating answer for question " Along with Dr. Coe, Bulman, Dorrance, C. Dana, and C. Dana, who is a notable physician? "...
# Done. Questions Left: 310
# Minutes Left: 204.10
# Generating answer for question " How many Townships are in range 15? "...
# Done. Questions Left: 309
# Minutes Left: 203.37
# Generating answer for question " Who was the only member of the Massachusetts Delegation who voted for General Jackson? "...
# Done. Questions Left: 308
# Minutes Left: 202.50
# Generating answer for question " What state did Coleman and Buford represent? "...
# Done. Questions Left: 307
# Minutes Left: 201.57
# Generating answer for question " How long was Mr. MILLER sentenced to imprisonment? "...
# Done. Questions Left: 306
# Minutes Left: 200.96
# Generating answer for question " Who was the guest of Mrs. Steele's parents? "...
# Done. Questions Left: 305
# Minutes Left: 200.57
# Generating answer for question " When was Phoebe's husband's marriage discovered? "...
# Done. Questions Left: 304
# Minutes Left: 199.95
# Generating answer for question " What constitutes three-fourths of the whole number of States in the United States? "...
# Done. Questions Left: 303
# Minutes Left: 199.50
# Generating answer for question " What party is R.B. Hos. Carson? "...
# Done. Questions Left: 302
# Minutes Left: 198.74
# Generating answer for question " The last publication of the petition and the order thereon is to be fourteen days, at least, before what date? "...
# Done. Questions Left: 301
# Minutes Left: 198.05
# Generating answer for question " Whose monopoly would the US trade be subjected to? "...
# Done. Questions Left: 300
# Minutes Left: 197.35
# Generating answer for question " Who's name is attached to a letter in the Argus? "...
# Done. Questions Left: 299
# Minutes Left: 196.61
# Generating answer for question " Who is the sole agent for the Pacific Coast? "...
# Done. Questions Left: 298
# Minutes Left: 196.05
# Generating answer for question " On what date did the Scourge arrive at Chatham? "...
# Done. Questions Left: 297
# Minutes Left: 195.39
# Generating answer for question " Who are most of the public prosecutors in Utah? "...
# Done. Questions Left: 296
# Minutes Left: 194.62
# Generating answer for question " Along with Jefferson and Newton, who adorned the Chair of Newton? "...
# Done. Questions Left: 295
# Minutes Left: 193.83
# Generating answer for question " What is the exchange rate between Cincinnati and New York? "...
# Done. Questions Left: 294
# Minutes Left: 193.03
# Generating answer for question " When did the Harrison Flag show the progress of the Southern Pacific Railroad? "...
# Done. Questions Left: 293
# Minutes Left: 192.21
# Generating answer for question " Which mining company's claim conflicts with the Justice and Inde pendent Mining Company's? "...
# Done. Questions Left: 292
# Minutes Left: 191.63
# Generating answer for question " What year will Oklahoma's land prices double? "...
# Done. Questions Left: 291
# Minutes Left: 191.02
# Generating answer for question " What war was the Grand Army of the Republic a part of? "...
# Done. Questions Left: 290
# Minutes Left: 190.22
# Generating answer for question " What state will be loaded on transport Berlin at Ponce? "...
# Done. Questions Left: 289
# Minutes Left: 189.47
# Generating answer for question " Who was the daughter of Russell Clarke, Esq.? "...
# Done. Questions Left: 288
# Minutes Left: 188.91
# Generating answer for question " Which party leads Tennessee in the race for governor? "...
# Done. Questions Left: 287
# Minutes Left: 188.19
# Generating answer for question " The William A. Clark awards are the largest prizes given in what country? "...
# Done. Questions Left: 286
# Minutes Left: 187.49
# Generating answer for question " Which state passed the law of 1833 that forbids the bringing of slaves into the State? "...
# Done. Questions Left: 285
# Minutes Left: 186.70
# Generating answer for question " Along with Macdonough, Nicholson and Galligher, who was a Captain on the Erie? "...
# Done. Questions Left: 284
# Minutes Left: 185.98
# Generating answer for question " Who played the title role in Henri Lavedan's comedy "Sire"? "...
# Done. Questions Left: 283
# Minutes Left: 185.13
# Generating answer for question " What day did the New York Herald say the Stock market evinced less activity October 29,1840? "...
# Done. Questions Left: 282
# Minutes Left: 184.42
# Generating answer for question " Who took it away from their successors for twenty years? "...
# Done. Questions Left: 281
# Minutes Left: 183.68
# Generating answer for question " In what state did Mr. Worble live? "...
# Done. Questions Left: 280
# Minutes Left: 182.98
# Generating answer for question " Who found a horse stolen from E.A. Moore? "...
# Done. Questions Left: 279
# Minutes Left: 182.28
# Generating answer for question " When was Souchong and English Breakfast Tea imported? "...
# Done. Questions Left: 278
# Minutes Left: 181.60
# Generating answer for question " In what city did a disgraceful riot take place on the 12th instant? "...
# Done. Questions Left: 277
# Minutes Left: 180.93
# Generating answer for question " Who deposited $15,000 in the Bank of Montana at Helena? "...
# Done. Questions Left: 276
# Minutes Left: 180.23
# Generating answer for question " Who did the Chicago Tribune comment on Cleveland's nomination as President? "...
# Done. Questions Left: 275
# Minutes Left: 179.88
# Generating answer for question " What is the name of Ribbeck's son? "...
# Done. Questions Left: 274
# Minutes Left: 179.44
# Generating answer for question " Who christened the banners of the Mexican army? "...
# Done. Questions Left: 273
# Minutes Left: 178.65
# Generating answer for question " When was the London Gazette's order in council dated? "...
# Done. Questions Left: 272
# Minutes Left: 177.88
# Generating answer for question " How many rubber pipes did Courbet use? "...
# Done. Questions Left: 271
# Minutes Left: 177.12
# Generating answer for question " Friends of what country will stop ratification of the League of Nations in the American congress if the Irish question is not settled? "...
# Done. Questions Left: 270
# Minutes Left: 176.38
# Generating answer for question " Who is the President of the People's Savings Bank of SACRAMENTO? "...
# Done. Questions Left: 269
# Minutes Left: 176.05
# Generating answer for question " What political party did the Hoodlums try to break up? "...
# Done. Questions Left: 268
# Minutes Left: 175.35
# Generating answer for question " Along with Baltimore and New York, what city is served by the Ohio & Mississippi R'y? "...
# Done. Questions Left: 267
# Minutes Left: 174.86
# Generating answer for question " What community is Baron Meyer de Rothschild a member of? "...
# Done. Questions Left: 266
# Minutes Left: 174.12
# Generating answer for question " Who is the 28 year old of Willis? "...
# Done. Questions Left: 265
# Minutes Left: 174.00
# Generating answer for question " How far away is Memphis from the Texarkana road? "...
# Done. Questions Left: 264
# Minutes Left: 173.25
# Minutes Left: 154.87
# Generating answer for question " How far from Natchez was Adams County, Mississippi? "...
# Done. Questions Left: 237
# Minutes Left: 154.10
# Generating answer for question " What political party did Buena Vista elect? "...
# Done. Questions Left: 236
# Minutes Left: 153.41
# Generating answer for question " How many west 6 poles 2 links to the northwest corner of lot 14? "...
# Done. Questions Left: 235
# Minutes Left: 152.81
# Generating answer for question " What is the number of common pleas court in which Michael Arnold was a judge? "...
# Done. Questions Left: 234
# Minutes Left: 152.15
# Generating answer for question " How long will credit be allowed on all sums over five dollars? "...
# Done. Questions Left: 233
# Minutes Left: 151.65
# Generating answer for question " Along with Alexandria and Alexandria, what state has a SCHOONER Regulator? "...
# Done. Questions Left: 232
# Minutes Left: 151.06
# Generating answer for question " How many of Chauncey's stories could the Grand Central depot not stand? "...
# Done. Questions Left: 231
# Minutes Left: 150.41
# Generating answer for question " Who is improving her opportunity, and learning of Lucy to cook every kind of flesh and fish, and to make cakes and pastry? "...
# Done. Questions Left: 230
# Minutes Left: 149.69
# Generating answer for question " Who is the manager of the Fox Park Timber company? "...
# Done. Questions Left: 229
# Minutes Left: 148.95
# Generating answer for question " How far from Montpelier Village is the farm formerly owned by Zadock Hubbard? "...
# Done. Questions Left: 228
# Minutes Left: 148.31
# Generating answer for question " How many cents was the advance of beef at $5.75? "...
# Done. Questions Left: 227
# Minutes Left: 147.80
# Generating answer for question " Who was the late C.E. Lampson's executor? "...
# Done. Questions Left: 226
# Minutes Left: 147.17
# Generating answer for question " Who was the leader of the enemy at Bamean? "...
# Done. Questions Left: 225
# Minutes Left: 146.47
# Generating answer for question " How far north of Point Reyes did the San Gabriel run ashore? "...
# Done. Questions Left: 224
# Minutes Left: 145.81
# Generating answer for question " How many men within a party in one state scratch the head of the ticket? "...
# Done. Questions Left: 223
# Minutes Left: 145.07
# Generating answer for question " How long is the front of the LOT of LAND on East Bay? "...
# Done. Questions Left: 222
# Minutes Left: 144.47
# Generating answer for question " Which New Jersey democrat is in the senate? "...
# Done. Questions Left: 221
# Minutes Left: 143.76
# Generating answer for question " How much of the April, 1911 receipts came from the Mayor's office? "...
# Done. Questions Left: 220
# Minutes Left: 143.33
# Generating answer for question " Along with Industries and Militia, what important committee is represented by Senator Voorhees? "...
# Done. Questions Left: 219
# Minutes Left: 142.61
# Generating answer for question " How many gentlemen had been at Washington? "...
# Done. Questions Left: 218
# Minutes Left: 141.85
# Generating answer for question " Which state seems to show that very strong influences will be brought to bear on Sec. Sherman to accept the republican nomination for governor? "...
# Done. Questions Left: 217
# Minutes Left: 141.37
# Generating answer for question " How many rooms does a 5 room bungalow have? "...
# Done. Questions Left: 216
# Minutes Left: 140.82
# Generating answer for question " How many lines are there in an ad for The Temple of Healing? "...
# Done. Questions Left: 215
# Minutes Left: 140.16
# Generating answer for question " Who opposed the German Parliamentary Committee's amendments to the Socialist bill? "...
# Done. Questions Left: 214
# Minutes Left: 139.42
# Generating answer for question " When was the case of Harrington vs. Wade set for trial? "...
# Done. Questions Left: 213
# Minutes Left: 138.70
# Generating answer for question " How many avowed advocates and missionaries of abolition did Garret and Williams have? "...
# Done. Questions Left: 186
# Minutes Left: 121.22
# Generating answer for question " Who was the son of Robert Chappell? "...
# Done. Questions Left: 185
# Minutes Left: 120.57
# Generating answer for question " Along with Walter Dauber and John Ohlweiler, who was elected president of the Trivoli? "...
# Done. Questions Left: 184
# Minutes Left: 119.89
# Generating answer for question " How many rooms does the John F. Bennett school have? "...
# Done. Questions Left: 183
# Minutes Left: 119.24
# Generating answer for question " How much did a young man spend a year for a library blessing? "...
# Done. Questions Left: 182
# Minutes Left: 118.62
# Generating answer for question " When was the Ordinance laid over Treasury Warrants? "...
# Done. Questions Left: 181
# Minutes Left: 118.06
# Generating answer for question " Who was a part of lot 38 105 35? "...
# Done. Questions Left: 180
# Minutes Left: 117.59
# Generating answer for question " Along with F. M. Ward, who lives at 87 Common street? "...
# Done. Questions Left: 179
# Minutes Left: 116.99
# Generating answer for question " How long will SUNDRY SLAVES be in the possession of Henry Bedinger? "...
# Done. Questions Left: 178
# Minutes Left: 116.37
# Generating answer for question " Who is the president of the United States? "...
# Done. Questions Left: 177
# Minutes Left: 115.62
# Generating answer for question " The United States shall pay one million two hundred and fifty thousand dollars to which state? "...
# ...
# Minutes Left: 70.95
# Generating answer for question " How many souls did Henry Trevor want to purchase? "...
# Done. Questions Left: 108
# Minutes Left: 70.30
# Generating answer for question " How many seconds was there silence at Debeuliam's auction? "...
# Done. Questions Left: 107
# Minutes Left: 69.78
# Generating answer for question " How old was Hannah Lee when her master's son came home? "...
# Done. Questions Left: 106
# Minutes Left: 69.09
# Generating answer for question " Who was appointed a Minister Plenipotentiary to Sweden? "...
# Done. Questions Left: 105
# Minutes Left: 68.42
# Generating answer for question " How many people are in Poland and Russia? "...
# Done. Questions Left: 104
# Minutes Left: 67.73
# Generating answer for question " How many revolutions a minute is the normal speed of the Friction machine? "...
# Done. Questions Left: 103
# Minutes Left: 67.08
# Generating answer for question " What country occupies a geographical position on the eastern portion of the Asiatic continent? "...
# Done. Questions Left: 102
# Minutes Left: 66.39
# Generating answer for question " Which state is excluded from the center of the United States? "...
# Done. Questions Left: 101
# Minutes Left: 65.71
# Generating answer for question " When did a very heavy rain fall in GLASGOW? "...
# Done. Questions Left: 100
# Minutes Left: 65.05
# Generating answer for question " Whose property is forbidden by law to be delivered to Sarah Platzek? "...
# Done. Questions Left: 99
# Minutes Left: 64.41
# Generating answer for question " How far west of the Burr Oak depot is the Grove Meeting? "...
# Done. Questions Left: 98
# Minutes Left: 63.77
# Generating answer for question " Who's troops are the Boer's unable to stand before? "...
# Done. Questions Left: 97
# Minutes Left: 63.09
# Generating answer for question " How much did Johnny think a drunkard's trouble would cost to nothing and a jail? "...
# Done. Questions Left: 96
# Minutes Left: 62.32
# Generating answer for question " What state's notion of breeding for size has been extending to Kentucky and western states for some years? "...
# Done. Questions Left: 95
# Minutes Left: 61.65
# Generating answer for question " How many times was the bill for abolishing the factory system of trade among the Indians read? "...
# Done. Questions Left: 94
# Minutes Left: 60.99
# Generating answer for question " Which party nominated E. M. Thompson for county auditor? "...
# Done. Questions Left: 93
# Minutes Left: 60.31
# Generating answer for question " Who convinced William M. Gait & Co. that an incendiary was responsible for the fire? "...
# Done. Questions Left: 92
# Minutes Left: 59.65
# Generating answer for question " Who issued an order of sale for Partition. vs. Christina Kimball? "...
# Done. Questions Left: 91
# Minutes Left: 58.97
# Generating answer for question " How many tenements did Messrs. Gibbons, Shad, Morrison and Hunter own? "...
# Done. Questions Left: 90
# Minutes Left: 58.33
# Generating answer for question " When was the land given to the city of Washington? "...
# Done. Questions Left: 89
# Minutes Left: 57.75
# Generating answer for question " In what state is Washington the most populous county? "...
# Done. Questions Left: 88
# Minutes Left: 57.06
# Generating answer for question " How far from the Ohio River is the Willow Glen Coal Property? "...
# Done. Questions Left: 87
# Minutes Left: 56.43
# Generating answer for question " What was the name of the court that convened February 25,1918 morning? "...
# Done. Questions Left: 86
# Minutes Left: 55.78
# Generating answer for question " Who should forward their orders without delay to secure chances for the Prizes contained in the following SPLENDID SCHEME? "...
# Done. Questions Left: 85
# Minutes Left: 55.12
# Generating answer for question " What is the name of Penn Traders' Bank? "...
# Done. Questions Left: 84
# Minutes Left: 54.52
# Generating answer for question " How much did the comptroller of the currency give to the creditors of the First National Bank of Franklin, Indiana? "...
# Done. Questions Left: 83
# Minutes Left: 53.87
# Generating answer for question " Which party saw a lot of happy faces this morning? "...
# Done. Questions Left: 82
# Minutes Left: 53.17
# Generating answer for question " How far from the river is 11 Arkansas? "...
# Done. Questions Left: 81
# Minutes Left: 52.53
# Generating answer for question " How far above the low water mark is the Tennessee River now? "...
# Done. Questions Left: 80
# Minutes Left: 51.90
# Generating answer for question " Who wrote to Mr. Tooks about his conviction that he received a fair majority of the votes of the county? "...
# Done. Questions Left: 79
# Minutes Left: 51.24
# Generating answer for question " How far from Port Tobacco is BROOMFIELD? "...
# Done. Questions Left: 78
# Minutes Left: 50.57
# Generating answer for question " Along with Clarence Hite, who was captured by John and Captain H. M. Craig? "...
# Done. Questions Left: 77
# Minutes Left: 49.91
# Generating answer for question " In what city was wheat five cents cheaper than corn? "...
# Done. Questions Left: 76
# Minutes Left: 49.25
# Generating answer for question " What political party did France belong to? "...
# Done. Questions Left: 75
# Minutes Left: 48.57
# Generating answer for question " How many gold fields are known as the "Old Field"? "...
# Done. Questions Left: 74
# Minutes Left: 47.89
# Generating answer for question " What party does J. H. Miller belong to? "...
# Done. Questions Left: 73
# Minutes Left: 47.23
# Generating answer for question " What year did ROBERT B. RUST receive his Cloths, Cassimeres, and Vestings? "...
# Done. Questions Left: 72
# Minutes Left: 46.58
# Generating answer for question " Who will take a few day boarders and also lodging and board for man and wife? "...
# Done. Questions Left: 71
# Minutes Left: 45.93
# Generating answer for question " The Cherokee Nation was considered a state of pupilage to what nation? "...
# Done. Questions Left: 70
# Minutes Left: 45.35
# Generating answer for question " When will Byron Davis and Frank Griggs have a family dinner? "...
# Done. Questions Left: 69
# Minutes Left: 44.68
# Generating answer for question " When did the Deputy Commissioner expect the Board of Estimate and Apportionment to provide for the contingency? "...
# Done. Questions Left: 68
# Minutes Left: 44.02
# Generating answer for question " What state is Cheyenne a part of? "...
# Done. Questions Left: 67
# Minutes Left: 43.35
# Generating answer for question " How many hhds of whiskey did J. MANDEVILLE Dave offer for sale? "...
# Done. Questions Left: 66
# Minutes Left: 42.71
# Generating answer for question " How much money did Mr. Luton lose? "...
# Done. Questions Left: 65
# Minutes Left: 42.05
# Generating answer for question " Near a third of the meat now sent to what city is brought in the form of dead meat? "...
# Done. Questions Left: 64
# Minutes Left: 41.40
# Generating answer for question " What country's Minister of War explained firing on US steamship Tennessee launch? "...
# Done. Questions Left: 63
# Minutes Left: 40.74
# Generating answer for question " Who was the confidential adviser of at Harper's Ferry? "...
# Done. Questions Left: 62
# Minutes Left: 40.08
# Generating answer for question " Whose views were expressed prior to 1800? "...
# Done. Questions Left: 61
# Minutes Left: 39.42
# Generating answer for question " A.B. Sholey was elected Judge of the 4th Judicial District, in place of who? "...
# Done. Questions Left: 60
# Minutes Left: 38.78
# Generating answer for question " What state wanted to nominate Judge Gray? "...
# Done. Questions Left: 59
# Minutes Left: 38.12
# Generating answer for question " Who did Walker serve a civil process on? "...
# Done. Questions Left: 58
# Minutes Left: 37.47
# Generating answer for question " How many people live in Lake City? "...
# Done. Questions Left: 57
# Minutes Left: 36.83
# Generating answer for question " How many students attended Rush's lectures in 1812? "...
# Done. Questions Left: 56
# Minutes Left: 36.18
# Generating answer for question " What religion is the Almanac for Illinois and Missouri? "...
# Done. Questions Left: 55
# Minutes Left: 35.53
# Generating answer for question " What body was Francis Lightfoot Lee a member of several times? "...
# Done. Questions Left: 54
# Minutes Left: 34.87
# Generating answer for question " How many kegs old Java Coffee are there? "...
# Done. Questions Left: 53
# Minutes Left: 34.24
# Generating answer for question " When did Clerks meet in New York? "...
# Done. Questions Left: 52
# Minutes Left: 33.58
# Generating answer for question " Along with the Courts of Petersburg, Berlin and what other city did the Prince Regent acknowledge the most cordial union and concert? "...
# Done. Questions Left: 51
# Minutes Left: 32.91
# Generating answer for question " When did the fire at Hilton break out again? "...
# Done. Questions Left: 50
# Minutes Left: 32.27
# Generating answer for question " Who made the 531 pieces of Luckypoors? "...
# Done. Questions Left: 49
# Minutes Left: 31.65
# Generating answer for question " Who is selling Sauerkrat in any quantity? "...
# Done. Questions Left: 48
# Minutes Left: 31.02
# Generating answer for question " Who was the Dealer in Lines suggested on reading the death of? "...
# Done. Questions Left: 47
# Minutes Left: 30.38
# Generating answer for question " How far below Custer is Robinson Bar? "...
# Done. Questions Left: 46
# Minutes Left: 29.73
# Generating answer for question " What city had 158 pounds of pork? "...
# Done. Questions Left: 45
# Minutes Left: 29.10
# Generating answer for question " How many feet is the bed room in the Villa? "...
# Done. Questions Left: 44
# Minutes Left: 28.46
# Generating answer for question " In what year was St. Martin's rebuilt? "...
# Done. Questions Left: 43
# Minutes Left: 27.81
# Generating answer for question " How much does it cost to send a large illustrated pamphlet on Urinary Diseases? "...
# Done. Questions Left: 42
# Minutes Left: 27.16
# Generating answer for question " How much would a year's subscription to The Phoenix cost a week? "...
# Done. Questions Left: 41
# Minutes Left: 26.51
# Generating answer for question " What is the name of Davis Kay's 2-year-old son? "...
# Done. Questions Left: 40
# Minutes Left: 25.87
# Generating answer for question " What month is the earliest for a general election? "...
# Done. Questions Left: 39
# Minutes Left: 25.22
# Generating answer for question " How much is the postage for all letters and packets not exceeding one ounce? "...
# Done. Questions Left: 38
# Minutes Left: 24.57
# Generating answer for question " Who wrote a letter to the Independent describing the trip from Salt Lake to San Francisco? "...
# Done. Questions Left: 37
# Minutes Left: 23.91
# Generating answer for question " When was the Colony of Georgia acknowledged to be one of the independent States of America? "...
# Done. Questions Left: 36
# Minutes Left: 23.26
# Generating answer for question " Who is waiting to know what Judge Chase thinks about the matter? "...
# Done. Questions Left: 35
# Minutes Left: 22.60
# Generating answer for question " Who took his seat when Wise's motion to lay the subject on the table for the present was adopted? "...
# Done. Questions Left: 34
# Minutes Left: 21.96
# Generating answer for question " On what day did Col. Blount and his daughter leave New York? "...
# Done. Questions Left: 33
# Minutes Left: 21.31
# Generating answer for question " Along with Youngstown, what city had a population of 31,895? "...
# Done. Questions Left: 32
# Minutes Left: 20.66
# Generating answer for question " In what state was the tavern next door to Woods' tavern located? "...
# Done. Questions Left: 31
# Minutes Left: 20.02
# Generating answer for question " When is the public worship service at 7:15? "...
# Done. Questions Left: 30
# Minutes Left: 19.38
# Generating answer for question " Who was the ex-President of the United States? "...
# Done. Questions Left: 29
# Minutes Left: 18.73
# Generating answer for question " Who was the father of Webster and Clay? "...
# Done. Questions Left: 28
# Minutes Left: 18.09
# Generating answer for question " How many females were confined in the State Prison on the first day of April, 1830 last? "...
# Done. Questions Left: 27
# Minutes Left: 17.44
# Generating answer for question " Who was Oti* Williams' wife? "...
# Done. Questions Left: 26
# Minutes Left: 16.79
# Generating answer for question " Along with H.S. Tate, who was a guest of Governor R.L. Williams at McAlester? "...
# Done. Questions Left: 25
# Minutes Left: 16.16
# Generating answer for question " The king of what country was determined upon an alliance with England by the king of Holstein? "...
# Done. Questions Left: 24
# Minutes Left: 15.50
# Generating answer for question " How wide was the beach when Elizabeth sat down? "...
# Done. Questions Left: 23
# Minutes Left: 14.87
# Generating answer for question " Who was Abram Col. Ford's father? "...
# Done. Questions Left: 22
# Minutes Left: 14.23
# Generating answer for question " What is the WHEAT number for CORN in St. Louis? "...
# Done. Questions Left: 21
# Minutes Left: 13.59
# Generating answer for question " Which state has a whig majority of ten on the joint ballot? "...
# Done. Questions Left: 20
# Minutes Left: 12.94
# Generating answer for question " Who was Thomas Whittaker accused of murdering? "...
# Done. Questions Left: 19
# Minutes Left: 12.29
# Generating answer for question " During what year were Bounty Bonds paid? "...
# Done. Questions Left: 18
# Minutes Left: 11.65
# Generating answer for question " Who is a member of the Mounted Rifles? "...
# Done. Questions Left: 17
# Minutes Left: 11.01
# Generating answer for question " How many Mexican yearlings-wethers are there? "...
# Done. Questions Left: 16
# Minutes Left: 10.37
# Generating answer for question " Whose steamboat went into the waters of New York? "...
# Done. Questions Left: 15
# Minutes Left: 9.72
# Generating answer for question " How much is the salary of the superintendent, assayer, coiner, and clerk in Charlotte, North Carolina? "...
# Done. Questions Left: 14
# Minutes Left: 9.07
# Generating answer for question " On what day did everyone want everyone else to be happy? "...
# Done. Questions Left: 13
# Minutes Left: 8.42
# Generating answer for question " On what day does the Steamboat Potomac arrive in Alexandria? "...
# Done. Questions Left: 12
# Minutes Left: 7.77
# Generating answer for question " How many words did the Quincy Whig say? "...
# Done. Questions Left: 11
# Minutes Left: 7.13
# Generating answer for question " How much money did Frances Thompson have in greenbacks? "...
# Done. Questions Left: 10
# Minutes Left: 6.48
# Generating answer for question " Who is the executor of the estate of William H. Wells, deceased? "...
# Done. Questions Left: 9
# Minutes Left: 5.83
# Generating answer for question " The first hostile gun that echoes along the valley of the Rio Grande will be the signal for a rally of what people? "...
# Done. Questions Left: 8
# Minutes Left: 5.18
# Generating answer for question " How many times did Samuel Haughton perform an operation on the paw of a tiger? "...
# Done. Questions Left: 7
# Minutes Left: 4.53
# Generating answer for question " Who did the United States Bank offer to advance a million immediately? "...
# Done. Questions Left: 6
# Minutes Left: 3.88
# Generating answer for question " Who assembled hist week at their council ground, fifteen miles from Columbus, for the purpose of taking into consideration, the wishes of the present administration? "...
# Done. Questions Left: 5
# Minutes Left: 3.23
# Generating answer for question " Along with Al Fairchild, William Hensel, George Waggoner, Charles Tucker and George Waggoner, who was also destroyed? "...
# Done. Questions Left: 4
# Minutes Left: 2.59
# Generating answer for question " On what date will the transfer books of the Phoenix National Bank be closed? "...
# Done. Questions Left: 3
# Minutes Left: 1.94
# Generating answer for question " How much land did Capt. F. buy on Buckner's Heights? "...
# Done. Questions Left: 2
# Minutes Left: 1.29
# Generating answer for question " Since what year has Illinois had a greater rate of population growth than any other state? "...
# Done. Questions Left: 1
# Minutes Left: 0.65
# Generating answer for question " How far from DeLand is the grove? "...
# Done. Questions Left: 0
# Minutes Left: 0.00

# %% [markdown]
# # 5. Model Evaluation

# %% [markdown]
# ## 5.1. Evaluation Prepration

# %%
# create a function to calculate metrics
tokenizer = nltk.tokenize.word_tokenize
stemmer = nltk.stem.snowball.SnowballStemmer("english")

def perform_evaluation(generated_answers: list, reference_answers: list) -> dict:
    precisions = []
    recalls = []
    cosines = []
    
    for gen_answer, ref_answer in zip(generated_answers, reference_answers, strict=True):
        gen_tokens = tokenizer(gen_answer)
        ref_tokens = tokenizer(ref_answer)

        # lemmatize tokens
        gen_lemmatized = (stemmer.stem(token) for token in gen_tokens)
        ref_lemmatized = (stemmer.stem(token) for token in ref_tokens)
        
        # transform into sets
        gen_set = set(gen_lemmatized)
        ref_set = set(ref_lemmatized)

        # calculate metrics for this example
        precisions.append(scores.precision(ref_set, gen_set))
        recalls.append(scores.recall(ref_set, gen_set))

        # embed answers
        gen_embedding = gpt4all_embedder.embed_query(gen_answer)
        ref_embedding = gpt4all_embedder.embed_query(ref_answer)

        # calculate cosine similarity for this example
        cosines.append(cosine_similarity([gen_embedding], [ref_embedding])[0][0])

    print("\tPrecision\tRecall\t\tCosine Similarity")
    print("Mean\t{:.6f}\t{:.6f}\t{:.6f}".format(mean(precisions), mean(recalls), mean(cosines)))
    print("Median\t{:.6f}\t{:.6f}\t{:.6f}".format(median(precisions), median(recalls), median(cosines)))
    print("Minimum\t{:.6f}\t{:.6f}\t{:.6f}".format(min(precisions), min(recalls), min(cosines)))
    print("Maximum\t{:.6f}\t{:.6f}\t{:.6f}".format(max(precisions), max(recalls), max(cosines)))
    if len(generated_answers) > 1:
        print("St.Dev.\t{:.6f}\t{:.6f}\t{:.6f}".format(stdev(precisions), stdev(recalls), stdev(cosines)))

# %%
# verify precision is calculated properly
perform_evaluation(
    [
        "These examples will have 100% precision.",
        "This is because excess tokens are not present."
    ],
    [
        "These examples will have 100% average precision over two examples.",
        "This is because excess tokens that are not in the reference answer are not present."
    ]
)
# Out:
# 	Precision	Recall		Cosine Similarity
# Mean	1.000000	0.685065	0.849552
# Median	1.000000	0.685065	0.849552
# Minimum	1.000000	0.642857	0.808039
# Maximum	1.000000	0.727273	0.891066
# St.Dev.	0.000000	0.059691	0.058708

# %%
# verify recall is calculated properly
perform_evaluation(
    [
        "These examples will have 100% average recall over two examples.",
        "This is because there are no tokens that are present in the reference answer that are also absent in the generated answer."
    ],
    [
        "These examples will have 100% recall.",
        "This is because there are no tokens that are absent."
    ]
)
# Out:
# 	Precision	Recall		Cosine Similarity
# Mean	0.657754	1.000000	0.722244
# Median	0.657754	1.000000	0.722244
# Minimum	0.588235	1.000000	0.559506
# Maximum	0.727273	1.000000	0.884983
# St.Dev.	0.098314	0.000000	0.230147

# %%
# verify cosine similarity is calculated properly
perform_evaluation(
    [
        "Perfect cosine similarity is practically impossible to demonstrate, \
        but two sentences with different words that mean the same should yield higher values for this metric than precision and recall.",
    ],
    [
        "It is impractical to show flawless cosine similarity, \
        but this metric should give higher values than recall & precision to two sentences with similar meanings, even if the words are dissimilar."
    ]
)
# Out:
# 	Precision	Recall		Cosine Similarity
# Mean	0.677419	0.677419	0.930462
# Median	0.677419	0.677419	0.930462
# Minimum	0.677419	0.677419	0.930462
# Maximum	0.677419	0.677419	0.930462

# %% [markdown]
# ## 5.2. Testing Over Sarawak Gazette QA Dataset

# %%
# load reference answers
reference_answers = []
with open(reference_answers_filepath, encoding="utf-8") as testing_file:
    for line in testing_file:
        if line.startswith("A: "):
            reference_answers.append(line[3:])
# verify reference answers are properly loaded
print("Reference Answers:", len(reference_answers))
print("Example:", reference_answers[0])
# Out:
# Reference Answers: 100
# Example: The reason for issuing notices prohibiting strangers from collecting fruit in certain Dyak areas was because they could not afford to offer them free board and lodging this season as is their usual custom, and they hoped to raise some ready cash by trading surplus fruit in the bazaars themselves, to augment their shortage of padi.

# %%
# load generated answers
file_path = Path(generated_answers_path)
generated_answers = []
for i in range(len(reference_answers)):
    with open(file_path / "saga" / (str(i+1) + '.txt'), encoding='utf-8') as generated_answer_file:
        generated_answers.append(generated_answer_file.read())
# verify generated answers are properly loaded
print("Generated Answers:", len(generated_answers))
print("Example:", generated_answers[0])
# Out:
# Generated Answers: 100
# Example:  The reason for issuing notices prohibiting strangers from collecting fruit in certain Dyak areas was to protect the ownership rights of the local Dyaks over their fruit trees and prevent disputes arising from outsiders encroaching on their lands or planting crops, such as rubber gardens, near their fruit groves.

# %%
# evaluate
perform_evaluation(generated_answers, reference_answers)
# Out:
# 	Precision	Recall		Cosine Similarity
# Mean	0.487864	0.430915	0.678473
# Median	0.494186	0.407077	0.719342
# Minimum	0.000000	0.000000	-0.066291
# Maximum	0.942857	0.938776	0.981141
# St.Dev.	0.196458	0.199531	0.218081

# %% [markdown]
# ## 5.3. Testing Over ChroniclingAmericaQA Dataset

# %%
# load JSON
reference_answers = []
with open(caqa_subset_filepath, encoding="utf-8") as testing_file:
    caqa_dataset = json.load(testing_file)
for example in caqa_dataset:
    reference_answers.append(example["answer"])

print("Reference Answers:", len(reference_answers))
print("Example:", reference_answers[0])
# Out:
# Reference Answers: 500
# Example: Thomas Sutton

# %%
# load generated answers
file_path = Path(generated_answers_path)
generated_answers = []
for i in range(len(reference_answers)):
    with open(file_path / "caqa" / (str(i+1) + '.txt'), encoding='utf-8') as generated_answer_file:
        generated_answers.append(generated_answer_file.read())
# verify generated answers are properly loaded
print("Generated Answers:", len(generated_answers))
print("Example:", generated_answers[0])
# Out:
# Generated Answers: 500
# Example:  The heads of Thomas Hendon were passed through by a road that was being considered for opening, commencing near Ruff's Mill and intersecting at a convenient point with the road leading from Schuck’s to Bull's Shops.

# %%
# evaluate
perform_evaluation(generated_answers, reference_answers)
# Out:
# 	Precision	Recall		Cosine Similarity
# Mean	0.076981	0.645786	0.311018
# Median	0.058824	1.000000	0.310754
# Minimum	0.000000	0.000000	-0.128224
# Maximum	0.800000	1.000000	0.818458
# St.Dev.	0.087765	0.448431	0.186698

# %% [markdown]
# # 6. User Interface
# Section 3 *must* be run before this section!

# %%
class MyWidget(QtWidgets.QDialog):
    start_message = "SYSTEM: Hello! I am a chatbot designed to answer questions related to the Sarawak Gazette. Type your question in the text box below."
    
    def __init__(self, invoke_func = None):
        super(MyWidget, self).__init__()
        self.invoke_func = invoke_func
        
        self.texts = QtWidgets.QLabel(self.start_message)
        self.text_input = QtWidgets.QLineEdit()
        self.button = QtWidgets.QPushButton("Send")
        self.button.clicked.connect(self.send_user_input)
        self.button.clicked.connect(self.text_input.clear)

        self.layout = QtWidgets.QVBoxLayout()
        self.layout.addWidget(self.texts)
        self.layout.addWidget(self.text_input)
        self.layout.addWidget(self.button)
        self.setLayout(self.layout)

    @QtCore.Slot()
    def send_user_input(self):
        question_str = self.text_input.text()
        self.texts.setText(self.texts.text() + "\nHUMAN: " + question_str)
        self.text_input.setText("")
        
        self.button.setText("Waiting for response, program may hang during this time...")
        if self.invoke_func:
            llm_response = self.invoke_func(question_str)
            self.texts.setText(self.texts.text() + "\nSYSTEM: " + llm_response)
            self.button.setText("Send")

# %%
if __name__ == '__main__':
    app = QtWidgets.QApplication([])

# %%
if __name__ == '__main__':
    widget = MyWidget(rag)
    widget.show()
    app.exec()
